# %%
# import libraries
import pandas as pd
from geopy import distance as dist

# %%
# constants
RADIUS = 100 # metres, approx. 330ft
ARRIVAL_SPEED = 20 # kph, approx 12.5 mph

# %%
# fetch data from csv
data = pd.read_csv("Heartbeats.csv")
data
# Out:
#      user_id user_role   timestamp  latitude  longitude  speed
# 0          7    driver  1669980219   18.0088   -76.7823     40
# 1          7    driver  1669980224   18.0090   -76.7822     40
# 2          7    driver  1669980229   18.0093   -76.7822     40
# 3          7    driver  1669980234   18.0096   -76.7820     40
# 4          7    driver  1669980239   18.0096   -76.7820     40
# ..       ...       ...         ...       ...        ...    ...
# 353        7    driver  1669981984   18.0054   -76.7477     40
# 354        7    driver  1669981989   18.0056   -76.7475     40
# 355        7    driver  1669981994   18.0058   -76.7474     32
# 356        7    driver  1669981999   18.0059   -76.7473     17
# 357        7    driver  1669982004   18.0059   -76.7473      0
#
# [358 rows x 6 columns]

# %%
# list of pickup points selected at random
locations = [57, 102, 168, 212, 281, 348, data.shape[0] - 1]
pickup_points = [];
for location in locations:
    pickup_points.append(data.loc[location, "latitude" : "longitude"])

# %%
# params: current_loc (data frame obj), dest (data frame obj)
def get_distance(curr_loc, dest): 
    # tuple(lat, lon)
    point_one = (curr_loc[0], curr_loc[1])
    point_two = (dest[0], dest[1])
    
    # calculate current distance in metres 
    return dist.great_circle(point_one, point_two).m

# %%
def main_no_speed():
    # heartbeat counter, passenger counter
    i, j = 0, 1
    
    # initialize prev_dist to inf  
    prev_dist = float("inf")
    
    while len(pickup_points) and i < data.shape[0]:
        # get curr_dist         
        curr_dist = get_distance(data.loc[i, "latitude":"longitude"], pickup_points[0])
        
        # not important -> only printing when approaching pickup point         
        if prev_dist > curr_dist:
            print("Index {}: Enroute to pickup point #{}. current distance: {:0.2f}km.".format(i, j, curr_dist / 1000))
        
        # driver is assumed to arrive when curr_dist < 100m 
        if curr_dist < RADIUS:
            if prev_dist < curr_dist:
                print("✅ Index {}: Picked up passenger(s), enroute to pickup point #{}.".format(i, j + 1))
                
                # dequeue current pickup point
                pickup_points.pop(0)
                j += 1
            else:
                print("🎯 Index {}: Within {:0.2f}m of pickup point #{}.".format(i, curr_dist, j))
        
        # set prev_dist to curr_dist while approaching pickup point, otherwise reset it to inf
        if prev_dist > curr_dist:
            prev_dist = curr_dist
        else:
            prev_dist = float("inf")
        
        # increment counter by 1
        i += 1

# %%
def main_with_speed():
    # heartbeat counter, passenger counter
    i, j = 0, 1

    while len(pickup_points) and i < data.shape[0]:
        # get curr_dist
        curr_dist = get_distance(data.loc[i, "latitude":"longitude"], pickup_points[0])
        speed = data.loc[i, "speed"]

        print("Index {}: Enroute to pickup point #{}. current distance: {:0.2f}km, current speed: {}kph.".format(i, j, curr_dist / 1000, speed))

        # driver is considered close when curr_dist < 100m and speed < 20kph
        if curr_dist <= RADIUS and speed <= ARRIVAL_SPEED:
            if speed == 0:
                print("✅ Index {}: Picked up passenger(s), enroute to pickup point #{}.".format(i, j + 1))

                # dequeue current pickup point
                pickup_points.pop(0)
                j += 1
            else:
                print("🎯 Index {}: Within {:0.2f}m of pickup point #{}, current speed: {}kph.".format(i, curr_dist, j, speed))
        i += 1

main_with_speed()
# Out:
# Index 0: Enroute to pickup point #1. current distance: 1.90km, current speed: 40kph.
# Index 1: Enroute to pickup point #1. current distance: 1.89km, current speed: 40kph.
# Index 2: Enroute to pickup point #1. current distance: 1.86km, current speed: 40kph.
# Index 3: Enroute to pickup point #1. current distance: 1.84km, current speed: 40kph.
# Index 4: Enroute to pickup point #1. current distance: 1.84km, current speed: 40kph.
# Index 5: Enroute to pickup point #1. current distance: 1.86km, current speed: 40kph.
# Index 6: Enroute to pickup point #1. current distance: 1.90km, current speed: 40kph.
# Index 7: Enroute to pickup point #1. current distance: 1.92km, current speed: 40kph.
# Index 8: Enroute to pickup point #1. current distance: 1.94km, current speed: 40kph.
# Index 9: Enroute to pickup point #1. current distance: 2.00km, current speed: 40kph.
# Index 10: Enroute to pickup point #1. current distance: 2.04km, current speed: 40kph.
# Index 11: Enroute to pickup point #1. current distance: 2.04km, current speed: 40kph.
# Index 12: Enroute to pickup point #1. current distance: 2.05km, current speed: 40kph.
# Index 13: Enroute to pickup point #1. current distance: 2.04km, current speed: 40kph.
# Index 14: Enroute to pickup point #1. current distance: 1.95km, current speed: 40kph.
# Index 15: Enroute to pickup point #1. current distance: 1.93km, current speed: 40kph.
# Index 16: Enroute to pickup point #1. current distance: 1.83km, current speed: 40kph.
# Index 17: Enroute to pickup point #1. current distance: 1.81km, current speed: 40kph.
# Index 18: Enroute to pickup point #1. current distance: 1.76km, current speed: 40kph.
# Index 19: Enroute to pickup point #1. current distance: 1.70km, current speed: 40kph.
# Index 20: Enroute to pickup point #1. current distance: 1.68km, current speed: 40kph.
# Index 21: Enroute to pickup point #1. current distance: 1.68km, current speed: 40kph.
# Index 22: Enroute to pickup point #1. current distance: 1.67km, current speed: 40kph.
# Index 23: Enroute to pickup point #1. current distance: 1.66km, current speed: 40kph.
# Index 24: Enroute to pickup point #1. current distance: 1.59km, current speed: 40kph.
# Index 25: Enroute to pickup point #1. current distance: 1.55km, current speed: 40kph.
# Index 26: Enroute to pickup point #1. current distance: 1.49km, current speed: 40kph.
# Index 27: Enroute to pickup point #1. current distance: 1.37km, current speed: 40kph.
# Index 28: Enroute to pickup point #1. current distance: 1.36km, current speed: 40kph.
# Index 29: Enroute to pickup point #1. current distance: 1.31km, current speed: 40kph.
# Index 30: Enroute to pickup point #1. current distance: 1.30km, current speed: 40kph.
# Index 31: Enroute to pickup point #1. current distance: 1.27km, current speed: 40kph.
# Index 32: Enroute to pickup point #1. current distance: 1.26km, current speed: 40kph.
# Index 33: Enroute to pickup point #1. current distance: 1.19km, current speed: 40kph.
# Index 34: Enroute to pickup point #1. current distance: 1.11km, current speed: 40kph.
# Index 35: Enroute to pickup point #1. current distance: 0.95km, current speed: 40kph.
# Index 36: Enroute to pickup point #1. current distance: 0.92km, current speed: 40kph.
# Index 37: Enroute to pickup point #1. current distance: 0.87km, current speed: 40kph.
# Index 38: Enroute to pickup point #1. current distance: 0.83km, current speed: 40kph.
# Index 39: Enroute to pickup point #1. current distance: 0.80km, current speed: 40kph.
# Index 40: Enroute to pickup point #1. current distance: 0.76km, current speed: 40kph.
# Index 41: Enroute to pickup point #1. current distance: 0.72km, current speed: 40kph.
# Index 42: Enroute to pickup point #1. current distance: 0.65km, current speed: 40kph.
# Index 43: Enroute to pickup point #1. current distance: 0.58km, current speed: 40kph.
# Index 44: Enroute to pickup point #1. current distance: 0.51km, current speed: 40kph.
# Index 45: Enroute to pickup point #1. current distance: 0.38km, current speed: 40kph.
# Index 46: Enroute to pickup point #1. current distance: 0.34km, current speed: 40kph.
# Index 47: Enroute to pickup point #1. current distance: 0.25km, current speed: 40kph.
# Index 48: Enroute to pickup point #1. current distance: 0.21km, current speed: 40kph.
# Index 49: Enroute to pickup point #1. current distance: 0.18km, current speed: 40kph.
# Index 50: Enroute to pickup point #1. current distance: 0.14km, current speed: 40kph.
# Index 51: Enroute to pickup point #1. current distance: 0.13km, current speed: 40kph.
# Index 52: Enroute to pickup point #1. current distance: 0.11km, current speed: 40kph.
# Index 53: Enroute to pickup point #1. current distance: 0.09km, current speed: 30kph.
# Index 54: Enroute to pickup point #1. current distance: 0.08km, current speed: 16kph.
# 🎯 Index 54: Within 77.84m of pickup point #1, current speed: 16kph.
# Index 55: Enroute to pickup point #1. current distance: 0.07km, current speed: 10kph.
# 🎯 Index 55: Within 66.72m of pickup point #1, current speed: 10kph.
# Index 56: Enroute to pickup point #1. current distance: 0.03km, current speed: 10kph.
# 🎯 Index 56: Within 34.99m of pickup point #1, current speed: 10kph.
# Index 57: Enroute to pickup point #1. current distance: 0.00km, current speed: 0kph.
# ✅ Index 57: Picked up passenger(s), enroute to pickup point #2.
# Index 58: Enroute to pickup point #2. current distance: 1.50km, current speed: 40kph.
# Index 59: Enroute to pickup point #2. current distance: 1.46km, current speed: 40kph.
# Index 60: Enroute to pickup point #2. current distance: 1.41km, current speed: 40kph.
# Index 61: Enroute to pickup point #2. current distance: 1.35km, current speed: 40kph.
# Index 62: Enroute to pickup point #2. current distance: 1.30km, current speed: 40kph.
# Index 63: Enroute to pickup point #2. current distance: 1.27km, current speed: 40kph.
# Index 64: Enroute to pickup point #2. current distance: 1.27km, current speed: 40kph.
# Index 65: Enroute to pickup point #2. current distance: 1.26km, current speed: 40kph.
# Index 66: Enroute to pickup point #2. current distance: 1.22km, current speed: 40kph.
# Index 67: Enroute to pickup point #2. current distance: 1.20km, current speed: 40kph.
# Index 68: Enroute to pickup point #2. current distance: 1.18km, current speed: 40kph.
# Index 69: Enroute to pickup point #2. current distance: 1.17km, current speed: 40kph.
# Index 70: Enroute to pickup point #2. current distance: 1.12km, current speed: 40kph.
# Index 71: Enroute to pickup point #2. current distance: 1.08km, current speed: 40kph.
# Index 72: Enroute to pickup point #2. current distance: 1.01km, current speed: 40kph.
# Index 73: Enroute to pickup point #2. current distance: 0.98km, current speed: 40kph.
# Index 74: Enroute to pickup point #2. current distance: 0.91km, current speed: 40kph.
# Index 75: Enroute to pickup point #2. current distance: 0.89km, current speed: 40kph.
# Index 76: Enroute to pickup point #2. current distance: 0.89km, current speed: 40kph.
# Index 77: Enroute to pickup point #2. current distance: 0.88km, current speed: 40kph.
# Index 78: Enroute to pickup point #2. current distance: 0.86km, current speed: 40kph.
# Index 79: Enroute to pickup point #2. current distance: 0.85km, current speed: 40kph.
# Index 80: Enroute to pickup point #2. current distance: 0.82km, current speed: 40kph.
# Index 81: Enroute to pickup point #2. current distance: 0.82km, current speed: 40kph.
# Index 82: Enroute to pickup point #2. current distance: 0.82km, current speed: 40kph.
# Index 83: Enroute to pickup point #2. current distance: 0.80km, current speed: 40kph.
# Index 84: Enroute to pickup point #2. current distance: 0.72km, current speed: 40kph.
# Index 85: Enroute to pickup point #2. current distance: 0.72km, current speed: 40kph.
# Index 86: Enroute to pickup point #2. current distance: 0.71km, current speed: 40kph.
# Index 87: Enroute to pickup point #2. current distance: 0.70km, current speed: 40kph.
# Index 88: Enroute to pickup point #2. current distance: 0.65km, current speed: 40kph.
# Index 89: Enroute to pickup point #2. current distance: 0.61km, current speed: 40kph.
# Index 90: Enroute to pickup point #2. current distance: 0.54km, current speed: 40kph.
# Index 91: Enroute to pickup point #2. current distance: 0.47km, current speed: 40kph.
# Index 92: Enroute to pickup point #2. current distance: 0.33km, current speed: 40kph.
# Index 93: Enroute to pickup point #2. current distance: 0.29km, current speed: 40kph.
# Index 94: Enroute to pickup point #2. current distance: 0.28km, current speed: 40kph.
# Index 95: Enroute to pickup point #2. current distance: 0.20km, current speed: 40kph.
# Index 96: Enroute to pickup point #2. current distance: 0.17km, current speed: 40kph.
# Index 97: Enroute to pickup point #2. current distance: 0.15km, current speed: 40kph.
# Index 98: Enroute to pickup point #2. current distance: 0.13km, current speed: 40kph.
# Index 99: Enroute to pickup point #2. current distance: 0.11km, current speed: 40kph.
# Index 100: Enroute to pickup point #2. current distance: 0.10km, current speed: 30kph.
# Index 101: Enroute to pickup point #2. current distance: 0.09km, current speed: 12kph.
# 🎯 Index 101: Within 88.58m of pickup point #2, current speed: 12kph.
# Index 102: Enroute to pickup point #2. current distance: 0.00km, current speed: 0kph.
# ✅ Index 102: Picked up passenger(s), enroute to pickup point #3.
# Index 103: Enroute to pickup point #3. current distance: 1.53km, current speed: 40kph.
# Index 104: Enroute to pickup point #3. current distance: 1.47km, current speed: 40kph.
# Index 105: Enroute to pickup point #3. current distance: 1.41km, current speed: 40kph.
# Index 106: Enroute to pickup point #3. current distance: 1.38km, current speed: 40kph.
# Index 107: Enroute to pickup point #3. current distance: 1.31km, current speed: 40kph.
# Index 108: Enroute to pickup point #3. current distance: 1.30km, current speed: 40kph.
# Index 109: Enroute to pickup point #3. current distance: 1.15km, current speed: 40kph.
# Index 110: Enroute to pickup point #3. current distance: 1.07km, current speed: 40kph.
# Index 111: Enroute to pickup point #3. current distance: 1.05km, current speed: 40kph.
# Index 112: Enroute to pickup point #3. current distance: 1.02km, current speed: 40kph.
# Index 113: Enroute to pickup point #3. current distance: 0.97km, current speed: 40kph.
# Index 114: Enroute to pickup point #3. current distance: 0.95km, current speed: 40kph.
# Index 115: Enroute to pickup point #3. current distance: 0.95km, current speed: 40kph.
# Index 116: Enroute to pickup point #3. current distance: 0.94km, current speed: 40kph.
# Index 117: Enroute to pickup point #3. current distance: 0.92km, current speed: 40kph.
# Index 118: Enroute to pickup point #3. current distance: 0.92km, current speed: 40kph.
# Index 119: Enroute to pickup point #3. current distance: 0.92km, current speed: 40kph.
# Index 120: Enroute to pickup point #3. current distance: 0.92km, current speed: 40kph.
# Index 121: Enroute to pickup point #3. current distance: 0.92km, current speed: 40kph.
# Index 122: Enroute to pickup point #3. current distance: 0.91km, current speed: 40kph.
# Index 123: Enroute to pickup point #3. current distance: 0.85km, current speed: 40kph.
# Index 124: Enroute to pickup point #3. current distance: 0.80km, current speed: 40kph.
# Index 125: Enroute to pickup point #3. current distance: 0.78km, current speed: 40kph.
# Index 126: Enroute to pickup point #3. current distance: 0.73km, current speed: 40kph.
# Index 127: Enroute to pickup point #3. current distance: 0.72km, current speed: 40kph.
# Index 128: Enroute to pickup point #3. current distance: 0.70km, current speed: 40kph.
# Index 129: Enroute to pickup point #3. current distance: 0.68km, current speed: 40kph.
# Index 130: Enroute to pickup point #3. current distance: 0.63km, current speed: 40kph.
# Index 131: Enroute to pickup point #3. current distance: 0.62km, current speed: 40kph.
# Index 132: Enroute to pickup point #3. current distance: 0.60km, current speed: 40kph.
# Index 133: Enroute to pickup point #3. current distance: 0.58km, current speed: 40kph.
# Index 134: Enroute to pickup point #3. current distance: 0.55km, current speed: 40kph.
# Index 135: Enroute to pickup point #3. current distance: 0.54km, current speed: 40kph.
# Index 136: Enroute to pickup point #3. current distance: 0.55km, current speed: 40kph.
# Index 137: Enroute to pickup point #3. current distance: 0.54km, current speed: 40kph.
# Index 138: Enroute to pickup point #3. current distance: 0.55km, current speed: 40kph.
# Index 139: Enroute to pickup point #3. current distance: 0.55km, current speed: 40kph.
# Index 140: Enroute to pickup point #3. current distance: 0.56km, current speed: 40kph.
# Index 141: Enroute to pickup point #3. current distance: 0.55km, current speed: 40kph.
# Index 142: Enroute to pickup point #3. current distance: 0.57km, current speed: 40kph.
# Index 143: Enroute to pickup point #3. current distance: 0.60km, current speed: 40kph.
# Index 144: Enroute to pickup point #3. current distance: 0.61km, current speed: 40kph.
# Index 145: Enroute to pickup point #3. current distance: 0.65km, current speed: 40kph.
# Index 146: Enroute to pickup point #3. current distance: 0.66km, current speed: 40kph.
# Index 147: Enroute to pickup point #3. current distance: 0.67km, current speed: 40kph.
# Index 148: Enroute to pickup point #3. current distance: 0.66km, current speed: 40kph.
# Index 149: Enroute to pickup point #3. current distance: 0.65km, current speed: 40kph.
# Index 150: Enroute to pickup point #3. current distance: 0.61km, current speed: 40kph.
# Index 151: Enroute to pickup point #3. current distance: 0.60km, current speed: 40kph.
# Index 152: Enroute to pickup point #3. current distance: 0.57km, current speed: 40kph.
# Index 153: Enroute to pickup point #3. current distance: 0.55km, current speed: 40kph.
# Index 154: Enroute to pickup point #3. current distance: 0.53km, current speed: 40kph.
# Index 155: Enroute to pickup point #3. current distance: 0.50km, current speed: 40kph.
# Index 156: Enroute to pickup point #3. current distance: 0.47km, current speed: 40kph.
# Index 157: Enroute to pickup point #3. current distance: 0.45km, current speed: 40kph.
# Index 158: Enroute to pickup point #3. current distance: 0.44km, current speed: 40kph.
# Index 159: Enroute to pickup point #3. current distance: 0.33km, current speed: 40kph.
# Index 160: Enroute to pickup point #3. current distance: 0.32km, current speed: 40kph.
# Index 161: Enroute to pickup point #3. current distance: 0.25km, current speed: 40kph.
# Index 162: Enroute to pickup point #3. current distance: 0.24km, current speed: 40kph.
# Index 163: Enroute to pickup point #3. current distance: 0.14km, current speed: 40kph.
# Index 164: Enroute to pickup point #3. current distance: 0.10km, current speed: 40kph.
# Index 165: Enroute to pickup point #3. current distance: 0.07km, current speed: 25kph.
# Index 166: Enroute to pickup point #3. current distance: 0.03km, current speed: 20kph.
# 🎯 Index 166: Within 34.99m of pickup point #3, current speed: 20kph.
# Index 167: Enroute to pickup point #3. current distance: 0.02km, current speed: 12kph.
# 🎯 Index 167: Within 15.34m of pickup point #3, current speed: 12kph.
# Index 168: Enroute to pickup point #3. current distance: 0.00km, current speed: 12kph.
# 🎯 Index 168: Within 0.00m of pickup point #3, current speed: 12kph.
# Index 169: Enroute to pickup point #3. current distance: 0.02km, current speed: 0kph.
# ✅ Index 169: Picked up passenger(s), enroute to pickup point #4.
# Index 170: Enroute to pickup point #4. current distance: 1.47km, current speed: 40kph.
# Index 171: Enroute to pickup point #4. current distance: 1.46km, current speed: 40kph.
# Index 172: Enroute to pickup point #4. current distance: 1.45km, current speed: 40kph.
# Index 173: Enroute to pickup point #4. current distance: 1.44km, current speed: 40kph.
# Index 174: Enroute to pickup point #4. current distance: 1.43km, current speed: 40kph.
# Index 175: Enroute to pickup point #4. current distance: 1.41km, current speed: 40kph.
# Index 176: Enroute to pickup point #4. current distance: 1.40km, current speed: 40kph.
# Index 177: Enroute to pickup point #4. current distance: 1.36km, current speed: 40kph.
# Index 178: Enroute to pickup point #4. current distance: 1.35km, current speed: 40kph.
# Index 179: Enroute to pickup point #4. current distance: 1.29km, current speed: 40kph.
# Index 180: Enroute to pickup point #4. current distance: 1.26km, current speed: 40kph.
# Index 181: Enroute to pickup point #4. current distance: 1.22km, current speed: 40kph.
# Index 182: Enroute to pickup point #4. current distance: 1.20km, current speed: 40kph.
# Index 183: Enroute to pickup point #4. current distance: 1.16km, current speed: 40kph.
# Index 184: Enroute to pickup point #4. current distance: 1.12km, current speed: 40kph.
# Index 185: Enroute to pickup point #4. current distance: 0.98km, current speed: 40kph.
# Index 186: Enroute to pickup point #4. current distance: 0.93km, current speed: 40kph.
# Index 187: Enroute to pickup point #4. current distance: 0.92km, current speed: 40kph.
# Index 188: Enroute to pickup point #4. current distance: 0.91km, current speed: 40kph.
# Index 189: Enroute to pickup point #4. current distance: 0.87km, current speed: 40kph.
# Index 190: Enroute to pickup point #4. current distance: 0.84km, current speed: 40kph.
# Index 191: Enroute to pickup point #4. current distance: 0.83km, current speed: 40kph.
# Index 192: Enroute to pickup point #4. current distance: 0.81km, current speed: 40kph.
# Index 193: Enroute to pickup point #4. current distance: 0.76km, current speed: 40kph.
# Index 194: Enroute to pickup point #4. current distance: 0.72km, current speed: 40kph.
# Index 195: Enroute to pickup point #4. current distance: 0.70km, current speed: 40kph.
# Index 196: Enroute to pickup point #4. current distance: 0.68km, current speed: 40kph.
# Index 197: Enroute to pickup point #4. current distance: 0.64km, current speed: 40kph.
# Index 198: Enroute to pickup point #4. current distance: 0.62km, current speed: 40kph.
# Index 199: Enroute to pickup point #4. current distance: 0.61km, current speed: 40kph.
# Index 200: Enroute to pickup point #4. current distance: 0.53km, current speed: 40kph.
# Index 201: Enroute to pickup point #4. current distance: 0.50km, current speed: 40kph.
# Index 202: Enroute to pickup point #4. current distance: 0.46km, current speed: 40kph.
# Index 203: Enroute to pickup point #4. current distance: 0.44km, current speed: 40kph.
# Index 204: Enroute to pickup point #4. current distance: 0.33km, current speed: 40kph.
# Index 205: Enroute to pickup point #4. current distance: 0.27km, current speed: 40kph.
# Index 206: Enroute to pickup point #4. current distance: 0.25km, current speed: 40kph.
# Index 207: Enroute to pickup point #4. current distance: 0.21km, current speed: 40kph.
# Index 208: Enroute to pickup point #4. current distance: 0.17km, current speed: 40kph.
# Index 209: Enroute to pickup point #4. current distance: 0.11km, current speed: 40kph.
# Index 210: Enroute to pickup point #4. current distance: 0.09km, current speed: 28kph.
# Index 211: Enroute to pickup point #4. current distance: 0.07km, current speed: 16kph.
# 🎯 Index 211: Within 71.68m of pickup point #4, current speed: 16kph.
# Index 212: Enroute to pickup point #4. current distance: 0.00km, current speed: 0kph.
# ✅ Index 212: Picked up passenger(s), enroute to pickup point #5.
# Index 213: Enroute to pickup point #5. current distance: 1.50km, current speed: 40kph.
# Index 214: Enroute to pickup point #5. current distance: 1.49km, current speed: 40kph.
# Index 215: Enroute to pickup point #5. current distance: 1.46km, current speed: 40kph.
# Index 216: Enroute to pickup point #5. current distance: 1.45km, current speed: 40kph.
# Index 217: Enroute to pickup point #5. current distance: 1.43km, current speed: 40kph.
# Index 218: Enroute to pickup point #5. current distance: 1.42km, current speed: 40kph.
# Index 219: Enroute to pickup point #5. current distance: 1.41km, current speed: 40kph.
# Index 220: Enroute to pickup point #5. current distance: 1.40km, current speed: 40kph.
# Index 221: Enroute to pickup point #5. current distance: 1.39km, current speed: 40kph.
# Index 222: Enroute to pickup point #5. current distance: 1.36km, current speed: 40kph.
# Index 223: Enroute to pickup point #5. current distance: 1.34km, current speed: 40kph.
# Index 224: Enroute to pickup point #5. current distance: 1.31km, current speed: 40kph.
# Index 225: Enroute to pickup point #5. current distance: 1.29km, current speed: 40kph.
# Index 226: Enroute to pickup point #5. current distance: 1.26km, current speed: 40kph.
# Index 227: Enroute to pickup point #5. current distance: 1.21km, current speed: 40kph.
# Index 228: Enroute to pickup point #5. current distance: 1.17km, current speed: 40kph.
# Index 229: Enroute to pickup point #5. current distance: 1.15km, current speed: 40kph.
# Index 230: Enroute to pickup point #5. current distance: 1.14km, current speed: 40kph.
# Index 231: Enroute to pickup point #5. current distance: 1.10km, current speed: 40kph.
# Index 232: Enroute to pickup point #5. current distance: 1.05km, current speed: 40kph.
# Index 233: Enroute to pickup point #5. current distance: 1.04km, current speed: 40kph.
# Index 234: Enroute to pickup point #5. current distance: 1.00km, current speed: 40kph.
# Index 235: Enroute to pickup point #5. current distance: 0.99km, current speed: 40kph.
# Index 236: Enroute to pickup point #5. current distance: 0.97km, current speed: 40kph.
# Index 237: Enroute to pickup point #5. current distance: 0.96km, current speed: 40kph.
# Index 238: Enroute to pickup point #5. current distance: 0.94km, current speed: 40kph.
# Index 239: Enroute to pickup point #5. current distance: 0.94km, current speed: 40kph.
# Index 240: Enroute to pickup point #5. current distance: 0.94km, current speed: 40kph.
# Index 241: Enroute to pickup point #5. current distance: 0.93km, current speed: 40kph.
# Index 242: Enroute to pickup point #5. current distance: 0.93km, current speed: 40kph.
# Index 243: Enroute to pickup point #5. current distance: 0.92km, current speed: 40kph.
# Index 244: Enroute to pickup point #5. current distance: 0.92km, current speed: 40kph.
# Index 245: Enroute to pickup point #5. current distance: 0.92km, current speed: 40kph.
# Index 246: Enroute to pickup point #5. current distance: 0.92km, current speed: 40kph.
# Index 247: Enroute to pickup point #5. current distance: 0.92km, current speed: 40kph.
# Index 248: Enroute to pickup point #5. current distance: 0.90km, current speed: 40kph.
# Index 249: Enroute to pickup point #5. current distance: 0.90km, current speed: 40kph.
# Index 250: Enroute to pickup point #5. current distance: 0.89km, current speed: 40kph.
# Index 251: Enroute to pickup point #5. current distance: 0.88km, current speed: 40kph.
# Index 252: Enroute to pickup point #5. current distance: 0.87km, current speed: 40kph.
# Index 253: Enroute to pickup point #5. current distance: 0.86km, current speed: 40kph.
# Index 254: Enroute to pickup point #5. current distance: 0.85km, current speed: 40kph.
# Index 255: Enroute to pickup point #5. current distance: 0.83km, current speed: 40kph.
# Index 256: Enroute to pickup point #5. current distance: 0.80km, current speed: 40kph.
# Index 257: Enroute to pickup point #5. current distance: 0.77km, current speed: 40kph.
# Index 258: Enroute to pickup point #5. current distance: 0.74km, current speed: 40kph.
# Index 259: Enroute to pickup point #5. current distance: 0.74km, current speed: 40kph.
# Index 260: Enroute to pickup point #5. current distance: 0.73km, current speed: 40kph.
# Index 261: Enroute to pickup point #5. current distance: 0.70km, current speed: 40kph.
# Index 262: Enroute to pickup point #5. current distance: 0.69km, current speed: 40kph.
# Index 263: Enroute to pickup point #5. current distance: 0.68km, current speed: 40kph.
# Index 264: Enroute to pickup point #5. current distance: 0.67km, current speed: 40kph.
# Index 265: Enroute to pickup point #5. current distance: 0.66km, current speed: 40kph.
# Index 266: Enroute to pickup point #5. current distance: 0.66km, current speed: 40kph.
# Index 267: Enroute to pickup point #5. current distance: 0.66km, current speed: 40kph.
# Index 268: Enroute to pickup point #5. current distance: 0.66km, current speed: 40kph.
# Index 269: Enroute to pickup point #5. current distance: 0.66km, current speed: 40kph.
# Index 270: Enroute to pickup point #5. current distance: 0.66km, current speed: 40kph.
# Index 271: Enroute to pickup point #5. current distance: 0.64km, current speed: 40kph.
# Index 272: Enroute to pickup point #5. current distance: 0.64km, current speed: 40kph.
# Index 273: Enroute to pickup point #5. current distance: 0.52km, current speed: 40kph.
# Index 274: Enroute to pickup point #5. current distance: 0.39km, current speed: 40kph.
# Index 275: Enroute to pickup point #5. current distance: 0.27km, current speed: 40kph.
# Index 276: Enroute to pickup point #5. current distance: 0.24km, current speed: 40kph.
# Index 277: Enroute to pickup point #5. current distance: 0.16km, current speed: 40kph.
# Index 278: Enroute to pickup point #5. current distance: 0.08km, current speed: 28kph.
# Index 279: Enroute to pickup point #5. current distance: 0.07km, current speed: 20kph.
# 🎯 Index 279: Within 67.55m of pickup point #5, current speed: 20kph.
# Index 280: Enroute to pickup point #5. current distance: 0.05km, current speed: 15kph.
# 🎯 Index 280: Within 45.72m of pickup point #5, current speed: 15kph.
# Index 281: Enroute to pickup point #5. current distance: 0.00km, current speed: 8kph.
# 🎯 Index 281: Within 0.00m of pickup point #5, current speed: 8kph.
# Index 282: Enroute to pickup point #5. current distance: 0.02km, current speed: 0kph.
# ✅ Index 282: Picked up passenger(s), enroute to pickup point #6.
# Index 283: Enroute to pickup point #6. current distance: 3.05km, current speed: 40kph.
# Index 284: Enroute to pickup point #6. current distance: 3.02km, current speed: 40kph.
# Index 285: Enroute to pickup point #6. current distance: 3.01km, current speed: 40kph.
# Index 286: Enroute to pickup point #6. current distance: 3.00km, current speed: 40kph.
# Index 287: Enroute to pickup point #6. current distance: 2.95km, current speed: 40kph.
# Index 288: Enroute to pickup point #6. current distance: 2.94km, current speed: 40kph.
# Index 289: Enroute to pickup point #6. current distance: 2.92km, current speed: 40kph.
# Index 290: Enroute to pickup point #6. current distance: 2.84km, current speed: 40kph.
# Index 291: Enroute to pickup point #6. current distance: 2.83km, current speed: 40kph.
# Index 292: Enroute to pickup point #6. current distance: 2.75km, current speed: 40kph.
# Index 293: Enroute to pickup point #6. current distance: 2.74km, current speed: 40kph.
# Index 294: Enroute to pickup point #6. current distance: 2.73km, current speed: 40kph.
# Index 295: Enroute to pickup point #6. current distance: 2.59km, current speed: 40kph.
# Index 296: Enroute to pickup point #6. current distance: 2.48km, current speed: 40kph.
# Index 297: Enroute to pickup point #6. current distance: 2.46km, current speed: 40kph.
# Index 298: Enroute to pickup point #6. current distance: 2.45km, current speed: 40kph.
# Index 299: Enroute to pickup point #6. current distance: 2.38km, current speed: 40kph.
# Index 300: Enroute to pickup point #6. current distance: 2.34km, current speed: 40kph.
# Index 301: Enroute to pickup point #6. current distance: 2.33km, current speed: 40kph.
# Index 302: Enroute to pickup point #6. current distance: 2.32km, current speed: 40kph.
# Index 303: Enroute to pickup point #6. current distance: 2.19km, current speed: 40kph.
# Index 304: Enroute to pickup point #6. current distance: 2.19km, current speed: 40kph.
# Index 305: Enroute to pickup point #6. current distance: 2.17km, current speed: 40kph.
# Index 306: Enroute to pickup point #6. current distance: 2.16km, current speed: 40kph.
# Index 307: Enroute to pickup point #6. current distance: 2.15km, current speed: 40kph.
# Index 308: Enroute to pickup point #6. current distance: 2.14km, current speed: 40kph.
# Index 309: Enroute to pickup point #6. current distance: 2.14km, current speed: 40kph.
# Index 310: Enroute to pickup point #6. current distance: 2.13km, current speed: 40kph.
# Index 311: Enroute to pickup point #6. current distance: 2.13km, current speed: 40kph.
# Index 312: Enroute to pickup point #6. current distance: 2.11km, current speed: 40kph.
# Index 313: Enroute to pickup point #6. current distance: 2.06km, current speed: 40kph.
# Index 314: Enroute to pickup point #6. current distance: 2.03km, current speed: 40kph.
# Index 315: Enroute to pickup point #6. current distance: 1.91km, current speed: 40kph.
# Index 316: Enroute to pickup point #6. current distance: 1.89km, current speed: 40kph.
# Index 317: Enroute to pickup point #6. current distance: 1.87km, current speed: 40kph.
# Index 318: Enroute to pickup point #6. current distance: 1.75km, current speed: 40kph.
# Index 319: Enroute to pickup point #6. current distance: 1.73km, current speed: 40kph.
# Index 320: Enroute to pickup point #6. current distance: 1.72km, current speed: 40kph.
# Index 321: Enroute to pickup point #6. current distance: 1.69km, current speed: 40kph.
# Index 322: Enroute to pickup point #6. current distance: 1.63km, current speed: 40kph.
# Index 323: Enroute to pickup point #6. current distance: 1.51km, current speed: 40kph.
# Index 324: Enroute to pickup point #6. current distance: 1.47km, current speed: 40kph.
# Index 325: Enroute to pickup point #6. current distance: 1.39km, current speed: 40kph.
# Index 326: Enroute to pickup point #6. current distance: 1.20km, current speed: 40kph.
# Index 327: Enroute to pickup point #6. current distance: 1.18km, current speed: 40kph.
# Index 328: Enroute to pickup point #6. current distance: 1.05km, current speed: 40kph.
# Index 329: Enroute to pickup point #6. current distance: 0.70km, current speed: 40kph.
# Index 330: Enroute to pickup point #6. current distance: 0.67km, current speed: 40kph.
# Index 331: Enroute to pickup point #6. current distance: 0.57km, current speed: 40kph.
# Index 332: Enroute to pickup point #6. current distance: 0.57km, current speed: 40kph.
# Index 333: Enroute to pickup point #6. current distance: 0.55km, current speed: 40kph.
# Index 334: Enroute to pickup point #6. current distance: 0.55km, current speed: 40kph.
# Index 335: Enroute to pickup point #6. current distance: 0.53km, current speed: 40kph.
# Index 336: Enroute to pickup point #6. current distance: 0.44km, current speed: 40kph.
# Index 337: Enroute to pickup point #6. current distance: 0.33km, current speed: 40kph.
# Index 338: Enroute to pickup point #6. current distance: 0.30km, current speed: 40kph.
# Index 339: Enroute to pickup point #6. current distance: 0.30km, current speed: 40kph.
# Index 340: Enroute to pickup point #6. current distance: 0.29km, current speed: 40kph.
# Index 341: Enroute to pickup point #6. current distance: 0.28km, current speed: 40kph.
# Index 342: Enroute to pickup point #6. current distance: 0.28km, current speed: 40kph.
# Index 343: Enroute to pickup point #6. current distance: 0.25km, current speed: 40kph.
# Index 344: Enroute to pickup point #6. current distance: 0.21km, current speed: 40kph.
# Index 345: Enroute to pickup point #6. current distance: 0.15km, current speed: 40kph.
# Index 346: Enroute to pickup point #6. current distance: 0.14km, current speed: 25kph.
# Index 347: Enroute to pickup point #6. current distance: 0.11km, current speed: 12kph.
# Index 348: Enroute to pickup point #6. current distance: 0.00km, current speed: 0kph.
# ✅ Index 348: Picked up passenger(s), enroute to pickup point #7.
# Index 349: Enroute to pickup point #7. current distance: 0.15km, current speed: 40kph.
# Index 350: Enroute to pickup point #7. current distance: 0.13km, current speed: 40kph.
# Index 351: Enroute to pickup point #7. current distance: 0.12km, current speed: 40kph.
# Index 352: Enroute to pickup point #7. current distance: 0.12km, current speed: 40kph.
# Index 353: Enroute to pickup point #7. current distance: 0.07km, current speed: 40kph.
# Index 354: Enroute to pickup point #7. current distance: 0.04km, current speed: 40kph.
# Index 355: Enroute to pickup point #7. current distance: 0.02km, current speed: 32kph.
# Index 356: Enroute to pickup point #7. current distance: 0.00km, current speed: 17kph.
# 🎯 Index 356: Within 0.00m of pickup point #7, current speed: 17kph.
# Index 357: Enroute to pickup point #7. current distance: 0.00km, current speed: 0kph.
# ✅ Index 357: Picked up passenger(s), enroute to pickup point #8.
